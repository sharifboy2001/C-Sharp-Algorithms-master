# %% [markdown]
# <a href="https://colab.research.google.com/github/sharifboy2001/C-Sharp-Algorithms-master/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
#Malumot yaratish
data =np.random.normal(size=100)
data

# %%
#matplotlip orqali grafik
plt.figure(figsize=(10,5))
plt. subplot(1,2,1)
plt.hist(data,bins=30,color='blue', edgecolor='black')
plt.title('Matplotlib Histogram')

#seaborn orqali grafik
plt.subplot(1,2,2)
sns.histplot(data,bins=30, color='blue')
plt.title('Seaborn Histogram')

plt.tight_layout()
plt.show()
